# %% [markdown]
# # Visualizing The Gender Gap In Salaries
#
# Visualizing the gender gap across college degrees.

# %% [markdown]
# ## Data description
# all_ages contain basic earnings and labor force information. recent-grads contains a more detailed breakdown, including by sex and by the type of job they got. grad-students contains details on graduate school attendees.
#
# Additionally, women-stem contains data for scatter plot in associated DataLab post on women in science/technology jobs. It is a subset of recent-grads
#
# Rank	Rank by median earnings
#
# Major_code	Major code, FO1DP in ACS PUMS
#
# Major	Major description
#
# Major_category	Category of major from Carnevale et al
#
# Total	Total number of people with major
#
# Sample_size	Sample size (unweighted) of full-time, year-round ONLY (used for earnings)
#
# Men	Male graduates
#
# Women	Female graduates
#
# ShareWomen	Women as share of total
#
# Employed	Number employed (ESR == 1 or 2)
#
# Full_time	Employed 35 hours or more
#
# Part_time	Employed less than 35 hours
#
# Full_time_year_round	Employed at least 50 weeks (WKW == 1) and at least 35 hours (WKHP >= 35)
#
# Unemployed	Number unemployed (ESR == 3)
#
# Unemployment_rate	Unemployed / (Unemployed + Employed)
#
# Median	Median earnings of full-time, year-round workers
#
# P25th	25th percentile of earnigns
#
# P75th	75th percentile of earnings
#
# College_jobs	Number with job requiring a college degree
#
# Non_college_jobs	Number with job not requiring a college degree
#
# Low_wage_jobs	Number in low-wage service jobs

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\OneDrive\\Desktop\\Data_Sets\\CollegeEarningsByMajors'

# %%
stem_women=pd.read_csv('C:\\Users\\hp\\OneDrive\\Desktop\\Data_Sets\\CollegeEarningsByMajors\\women-stem.csv',
                         encoding='Utf')
recent_grads=pd.read_csv('C:\\Users\\hp\\OneDrive\\Desktop\\Data_Sets\\CollegeEarningsByMajors\\recent-grads.csv',
                         encoding='Utf')
all_ages=pd.read_csv('C:\\Users\\hp\\OneDrive\\Desktop\\Data_Sets\\CollegeEarningsByMajors\\all-ages.csv',
                         encoding='Utf')
grad_students=pd.read_csv('C:\\Users\\hp\\OneDrive\\Desktop\\Data_Sets\\CollegeEarningsByMajors\\grad-students.csv',
                         encoding='Utf')
print('STEM_WOMEN')
display(stem_women.head())
print('RECENT_GRADS')
display(recent_grads.head())
print('ALL_AGES')
display(all_ages.head())
print('GRAD_STUDENTS')
display(grad_students.head())
# Out:
# STEM_WOMEN
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000
# RECENT_GRADS
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# ...

# %% [markdown]
# We will be using the recent_grads dataframe since it has details for both Men & Women.
# ### we first drop rows with null values

# %%
display(recent_grads.head(3))
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
# 2     3        2415       METALLURGICAL ENGINEERING   856.0   725.0  131.0
#
#   Major_category  ShareWomen  Sample_size  Employed  ...  Part_time  \
# 0    Engineering    0.120564           36      1976  ...        270
# 1    Engineering    0.101852            7       640  ...        170
# 2    Engineering    0.153037            3       648  ...        133
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
# 2                   340          16           0.024096   73000  50000  105000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# ...

# %%
stem_cats=['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
